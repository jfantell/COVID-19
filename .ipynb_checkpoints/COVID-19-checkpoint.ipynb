# %% [markdown]
# # MODELING COVID-19
# * Data Source: Johns Hopkins CSSE
# * Based on kernel: https://www.kaggle.com/tarunkr/covid-19-case-study-analysis-viz-comparisons
# * John Hopkins Desktop Visualization: https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker 
import pycountry_convert as pc
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.cbook as cbook
import folium
import branca
import plotly.express as px
import json, requests
import calmap
import datetime
import geopandas
import shapely

# Matplotlib 
# %matplotlib inline
plt.rcParams.update(
    {
        "figure.figsize":(20,10),
        "font.sans-serif": "Helvetica",
        "font.weight": "bold",
        "font.size": 22
    })

# %% [markdown]
# ## Data Preparation

# %%
# Timeseries data for all countries
df_confirmed = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
df_deaths = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
df_recovered = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')

# %%
# Latest up to date COVID-19 for all countries
df_covid_latest = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/web-data/data/cases_country.csv")

# %%
# Preview
df_covid_latest.head(5)
# Out:
#   Country_Region          Last_Update      Lat     Long_  Confirmed  Deaths  \
# 0      Australia  2020-04-29 01:32:25 -25.0000  133.0000       6744      89
# 1        Austria  2020-04-29 01:32:25  47.5162   14.5501      15357     569
# 2         Canada  2020-04-29 01:32:25  60.0010  -95.0010      51150    2983
# 3          China  2020-04-29 01:32:25  30.5928  114.3055      83938    4637
# 4        Denmark  2020-04-29 01:32:25  56.0000   10.0000       9049     434
#
#    Recovered  Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 0       5663     992      26.488922            NaN                  NaN
# 1      12580    2208     170.512080            NaN                  NaN
# 2      19231   28936     135.118350            NaN                  NaN
# 3      78410     891       5.975611            NaN                  NaN
# 4       6313    2302     156.227259            NaN                  NaN
#
#    Mortality_Rate  UID ISO3
# 0        1.319692   36  AUS
# 1        3.705151   40  AUT
# 2        5.831867  124  CAN
# 3        5.524316  156  CHN
# 4        4.796110  208  DNK

# %%
# Rename Country columns so that all columns have consistant naming convention
# Source: https://www.kaggle.com/tarunkr/covid-19-case-study-analysis-viz-comparisons
df_confirmed = df_confirmed.rename(columns={"Province/State":"state","Country/Region": "Country"})
df_deaths = df_deaths.rename(columns={"Province/State":"state","Country/Region": "Country"})
df_recovered = df_recovered.rename(columns={"Province/State":"state","Country/Region": "Country"})
df_covid_latest = df_covid_latest.rename(columns={"Country_Region": "Country"})

# %%
# Add continent data to each dataframe
# Modified from: https://www.kaggle.com/tarunkr/covid-19-case-study-analysis-viz-comparisons
def rename_country(dataframe,countries):
    for country in countries:
        dataframe.loc[dataframe['Country'] == country, "Country"] = countries[country]

mapping = {'US':'USA','Korea, South':'South Korea','Taiwan*':'Taiwan','Congo (Kinshasa)':'Democratic Republic of the Congo',"Cote d'Ivoire":"Côte d'Ivoire","Reunion":"Réunion","Congo (Brazzaville)":"Republic of the Congo","Bahamas, The":"Bahamas","Gambia, The":"Gambia"}
rename_country(df_confirmed,mapping)
rename_country(df_deaths,mapping)
rename_country(df_recovered,mapping)
rename_country(df_covid_latest,mapping)

# Continent_code to Continent_names
continents = {
    'NA': 'North America',
    'SA': 'South America', 
    'AS': 'Asia',
    'OC': 'Australia',
    'AF': 'Africa',
    'EU' : 'Europe',
    'na' : 'Others'
}

# Defininng Function for getting continent code for country.
def country_to_continent_code(country):
    try:
        return pc.country_alpha2_to_continent_code(pc.country_name_to_country_alpha2(country))
    except :
        return 'na'

# Collecting Continent Information
df_confirmed['Continent'] = df_confirmed['Country'].apply(lambda country: continents[country_to_continent_code(country)])
df_deaths['Continent'] = df_deaths['Country'].apply(lambda country: continents[country_to_continent_code(country)])
df_recovered['Continent'] = df_recovered['Country'].apply(lambda country: continents[country_to_continent_code(country)])
df_covid_latest['Continent'] = df_covid_latest['Country'].apply(lambda country: continents[country_to_continent_code(country)])

# %% [markdown]
# ## Latest COVID-19 Statistics

# %%
# Plot current snapshot of COVID-19 data
def plot_bar(dataframe,dimensions='Country',measure='Mortality_Rate',x_axis='Country',y_axis='Moratliy Rate (%)',title='Morality Rate By Country',color='r'):
    # Global Summary
    dataframe = dataframe.sort_values(by=measure,ascending=False).head(7)
    fig, ax = plt.subplots()
    ax.set_ylabel(y_axis,labelpad=20)
    ax.set_title(title,pad=20)
    ax.set_xlabel(x_axis,labelpad=20)
    dimension_labels = list(dataframe.index)
    measure_values = list(dataframe[measure].values)
    ax.bar(dimension_labels,measure_values,color=color)
    fig.autofmt_xdate()
    plt.show()

# Apply a color map to a dataframe
def style(dataframe,sortby='Confirmed'):
    return dataframe.sort_values(by=sortby,ascending=False).head(7).style.set_precision(2).background_gradient(cmap='Blues',subset=["Confirmed"])\
                            .background_gradient(cmap='Purples',subset=["Deaths"])\
                            .background_gradient(cmap='Oranges',subset=["Recovered"])\
                            .background_gradient(cmap='Reds',subset=["Active"])\
                            .background_gradient(cmap='Blues',subset=["Incident_Rate"])\
                            .background_gradient(cmap='Purples',subset=["Mortality_Rate"])

# Generate an aggegate dataframe given a dimension and measure
# Currently supports two dimensions: Continent, Country
def generate(dataframe,dimension='Continent'):
    drop_column = 'Country'
    if dimension=='Country':
        drop_column = 'Continent'
    dataframe_ = dataframe.copy().drop(['Lat','Long_','UID','ISO3','People_Hospitalized','People_Tested','Last_Update','Mortality_Rate',drop_column],axis=1)
    dataframe_.fillna(0,inplace=True)
    dataframe_ = dataframe_.groupby(dimension).sum()
    
    # Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
    dataframe_["Mortality_Rate"] = np.round(100*dataframe_["Deaths"]/dataframe_["Confirmed"],2)
    
    #Incident_Rate - confirmed cases per 100,000 persons.
    dataframe_["Incident_Rate"] = np.round(dataframe_["Confirmed"]/100000,2)
    return dataframe_

# %%
# Create bar charts expressing the latest COVID-19 statistics for each continent
df_continents = generate(df_covid_latest,dimension='Continent')
plot_bar(df_continents,dimensions='Continent',measure='Mortality_Rate',x_axis='Continent',y_axis='Moratliy Rate (%)',title='COVID-19 Morality Rate By Continent',color='b')

# %% [markdown]
# ### Figure 1

# %%
plot_bar(df_continents,dimensions='Continent',measure='Confirmed',x_axis='Continent',y_axis='# Confirmed Cases',title='Confirmed Cases of COVID-19 By Continent',color='g')

# %% [markdown]
# ### Figure 2

# %%
plot_bar(df_continents,dimensions='Continent',measure='Active',x_axis='Continent',y_axis='# Active Cases',title='Active Cases of COVID-19 By Continent',color='y')

# %% [markdown]
# ### Figure 3

# %%
plot_bar(df_continents,dimensions='Continent',measure='Deaths',x_axis='Continent',y_axis='# Deaths',title='Deaths Due to COVID-19 By Continent',color='m')

# %% [markdown]
# ### Figure 4

# %%
plot_bar(df_continents,dimensions='Continent',measure='Incident_Rate',x_axis='Continent',y_axis='# Confirmed Cases per 100,000 people',title='COVID-19 Incident Rate By Continent',color='r')

# %% [markdown]
# ### Figure 5

# %% [markdown]
# ### Table 1: Latest COVID-1 Statistics (Continent-wise)

# %%
style(df_continents,sortby='Confirmed')
# Out:
# <style  type="text/css" >
#     #T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col2 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col3 {
#             background-color:  #b11218;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col5 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col0 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col1 {
#             background-color:  #9e9ac8;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col2 {
#             background-color:  #fdbd83;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col4 {
#             background-color:  #115ca5;
#             color:  #f1f1f1;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col5 {
#             background-color:  #9390c3;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow2_col0 {
#             background-color:  #9fcae1;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow2_col1 {
#             background-color:  #ecebf4;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow2_col2 {
#             background-color:  #fa8331;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow2_col3 {
#             background-color:  #fcb89e;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow2_col4 {
#             background-color:  #9fcae1;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow2_col5 {
#             background-color:  #d3d3e8;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow3_col0 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow3_col1 {
#             background-color:  #f6f4f9;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow3_col2 {
#             background-color:  #fee7d1;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow3_col3 {
#             background-color:  #fee4d8;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow3_col4 {
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow3_col5 {
#             background-color:  #aeadd3;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow4_col0 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow4_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow4_col2 {
#             background-color:  #fff3e6;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow4_col3 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow4_col4 {
#             background-color:  #f2f8fd;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow4_col5 {
#             background-color:  #bdbedc;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow5_col0 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow5_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow5_col2 {
#             background-color:  #fff4e8;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow5_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow5_col4 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow5_col5 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow6_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow6_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow6_col2 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow6_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow6_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_57484272_89c2_11ea_91f0_a45e60e6597brow6_col5 {
#             background-color:  #f4f3f8;
#             color:  #000000;
#         }</style><table id="T_57484272_89c2_11ea_91f0_a45e60e6597b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>        <th class="col_heading level0 col4" >Incident_Rate</th>        <th class="col_heading level0 col5" >Mortality_Rate</th>    </tr>    <tr>        <th class="index_name level0" >Continent</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_57484272_89c2_11ea_91f0_a45e60e6597blevel0_row0" class="row_heading level0 row0" >Europe</th>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col0" class="data row0 col0" >1324403</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col1" class="data row0 col1" >126439</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col2" class="data row0 col2" >459903</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col3" class="data row0 col3" >738061</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col4" class="data row0 col4" >13.24</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow0_col5" class="data row0 col5" >9.55</td>
#             </tr>
#             <tr>
#                         <th id="T_57484272_89c2_11ea_91f0_a45e60e6597blevel0_row1" class="row_heading level0 row1" >North America</th>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col0" class="data row1 col0" >1097426</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col1" class="data row1 col1" >63558</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col2" class="data row1 col2" >149522</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col3" class="data row1 col3" >884346</td>
#                         <td id="T_57484272_89c2_11ea_91f0_a45e60e6597brow1_col4" class="data row1 col4" >10.97</td>
#                         <td

# %%
# Create bar charts expressing the latest COVID-19 statistics for each country
# Show only the most 7 affected countries for each statistic
df_countries = generate(df_covid_latest,dimension='Country')
plot_bar(df_countries,dimensions='Country',measure='Mortality_Rate',x_axis='Country',y_axis='Moratliy Rate (%)',title='COVID-19 Morality Rate By Country',color='b')

# %% [markdown]
# ### Figure 6

# %%
plot_bar(df_countries,dimensions='Country',measure='Confirmed',x_axis='Country',y_axis='# Confirmed Cases',title='Confirmed Cases of COVID-19 By Country',color='g')

# %% [markdown]
# ### Figure 7

# %%
plot_bar(df_countries,dimensions='Country',measure='Active',x_axis='Country',y_axis='# Active Cases',title='Active Cases of COVID-19 By Country',color='y')

# %% [markdown]
# ### Figure 8

# %%
plot_bar(df_countries,dimensions='Country',measure='Deaths',x_axis='Country',y_axis='# Deaths',title='Deaths Due to COVID-19 By Country',color='m')

# %% [markdown]
# ### Figure 9

# %%
plot_bar(df_countries,dimensions='Country',measure='Incident_Rate',x_axis='Country',y_axis='# Confirmed Cases per 100,000 people',title='COVID-19 Incident Rate By Country',color='r')

# %% [markdown]
# ### Figure 10

# %% [markdown]
# ### Table 2: Latest COVID-1 Statistics (Country-wise)

# %%
style(df_countries.head(20),sortby='Confirmed')
# Out:
# <style  type="text/css" >
#     #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col1 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col2 {
#             background-color:  #a83703;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col3 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col5 {
#             background-color:  #3f007d;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col0 {
#             background-color:  #c1d9ed;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col1 {
#             background-color:  #f5f4f9;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col2 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col3 {
#             background-color:  #ffeee6;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col4 {
#             background-color:  #c4daee;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col5 {
#             background-color:  #e2e1ef;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow2_col0 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow2_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow2_col2 {
#             background-color:  #fee2c6;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow2_col3 {
#             background-color:  #fca285;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow2_col4 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow2_col5 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow3_col0 {
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow3_col1 {
#             background-color:  #fcfbfd;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow3_col2 {
#             background-color:  #fd9c51;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow3_col3 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow3_col4 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow3_col5 {
#             background-color:  #f8f6fa;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow4_col0 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow4_col1 {
#             background-color:  #fbfafc;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow4_col2 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow4_col3 {
#             background-color:  #fdcebb;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow4_col4 {
#             background-color:  #eef5fc;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow4_col5 {
#             background-color:  #f0eef5;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow5_col0 {
#             background-color:  #f5fafe;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow5_col1 {
#             background-color:  #faf9fc;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow5_col2 {
#             background-color:  #feebd8;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow5_col3 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow5_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow5_col5 {
#             background-color:  #cfd0e6;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow6_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow6_col1 {
#             background-color:  #f7f6fa;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow6_col2 {
#             background-color:  #fee6cf;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow6_col3 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow6_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_6c331be4_89c2_11ea_91f0_a45e60e6597brow6_col5 {
#             background-color:  #674ca1;
#             color:  #f1f1f1;
#         }</style><table id="T_6c331be4_89c2_11ea_91f0_a45e60e6597b" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Confirmed</th>        <th class="col_heading level0 col1" >Deaths</th>        <th class="col_heading level0 col2" >Recovered</th>        <th class="col_heading level0 col3" >Active</th>        <th class="col_heading level0 col4" >Incident_Rate</th>        <th class="col_heading level0 col5" >Mortality_Rate</th>    </tr>    <tr>        <th class="index_name level0" >Country</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6c331be4_89c2_11ea_91f0_a45e60e6597blevel0_row0" class="row_heading level0 row0" >Belgium</th>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col0" class="data row0 col0" >47334</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col1" class="data row0 col1" >7331</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col2" class="data row0 col2" >10943</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col3" class="data row0 col3" >29060</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col4" class="data row0 col4" >0.47</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow0_col5" class="data row0 col5" >15.49</td>
#             </tr>
#             <tr>
#                         <th id="T_6c331be4_89c2_11ea_91f0_a45e60e6597blevel0_row1" class="row_heading level0 row1" >Austria</th>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col0" class="data row1 col0" >15357</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col1" class="data row1 col1" >569</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col2" class="data row1 col2" >12580</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col3" class="data row1 col3" >2208</td>
#                         <td id="T_6c331be4_89c2_11ea_91f0_a45e60e6597brow1_col4" class="data row1 col4" >0.15</td>
#                         <td id="T_6c331be4_89c2_

# %% [markdown]
# ## Basic Timeseries Plots

# %%
# Plot timeseries data as a line plot
def plot_line(dataframe,title='COVID-19 Cases Over Time: Globally',x_axis='Date',y_axis='Daily Cases'):
    dataframe.dropna(axis=0,inplace=True)
    dates = [datetime.datetime.strptime(str(date), '%m/%d/%y') for date in dataframe.index]

    fig, ax = plt.subplots()
    years = mdates.YearLocator()   # every year
    months = mdates.MonthLocator()  # every month
    days = mdates.DayLocator()
    # years_fmt = mdates.DateFormatter('%Y')
    
    for column in dataframe.columns:
        ax.plot(dates,dataframe[column],label=f"{column} cases")
    ax.legend(loc="upper left")
    # format the ticks
    # ax.xaxis.set_major_locator(years)
    # ax.xaxis.set_major_formatter(years_fmt)
    # ax.xaxis.set_major_locator(months)
    # ax.xaxis.set_minor_locator(days)
    
    ax.set_ylabel(y_axis,labelpad=20)
    ax.set_title(title,pad=20)
    ax.set_xlabel(x_axis,labelpad=20)

    # round to nearest years.
    datemin = np.datetime64(dates[0], 'M')
    datemax = np.datetime64(dates[-1], 'M') + np.timedelta64(1, 'M')
    ax.set_xlim(datemin, datemax)

    # format the coords message box
    ax.format_xdata = mdates.DateFormatter('%Y-%m-%d')
    # ax.format_ydata = lambda x: '%1.2f' % x  # format the price.
    ax.grid(True)

    fig.autofmt_xdate()

# %%
# Utility function of make_dataframe
# used to preprocess timeseries data such that it can be combined
# with other timeseries data
# Location type can be either continent or country at this time
def make_series(dataframe,name,location_type=None,location=None):
    if location_type == None:
        series = pd.Series(dataframe.drop(['state','Continent','Country','Lat','Long'],axis=1).sum(),name=name)
    else:
        series = pd.Series(dataframe[dataframe[location_type] == location].drop(['state','Continent','Country','Lat','Long'],axis=1).sum(),name=name)
    series.dropna(axis=0,inplace=True)
    return series

# Create a dataframe that encompasses all timeseries
# data: i.e. confirmed cases, deaths, recovered cases
def make_dataframe(dataframes,columns,location_type=None,location=None):
    series_list = []
    for (d,c) in zip(dataframes,columns):
        series_list.append(make_series(d,c,location_type,location))
    dataframe = pd.concat(series_list, axis=1)
    return dataframe

# %%
global_timeseries_data = make_dataframe([df_confirmed,df_deaths,df_recovered],['Confirmed','Deaths','Recovered'])
plot_line(global_timeseries_data,title='COVID-19 Cumulative Cases Over Time: Global',x_axis='Date',y_axis='# Cumulative Cases')

# %% [markdown]
# ### Figure 11

# %%
plot_line(global_timeseries_data.diff(),title='COVID-19 New Cases Over Time: Global',x_axis='Date',y_axis='# New Cases')

# %% [markdown]
# ### Figure 12

# %%
usa_timeseries_data = make_dataframe([df_confirmed,df_deaths,df_recovered],['Confirmed','Deaths','Recovered'],'Country','USA')
plot_line(usa_timeseries_data,title='COVID-19 Cumulative Cases Over Time: USA',x_axis='Date',y_axis='# Cumulative Cases')

# %% [markdown]
# ### Figure 13

# %%
plot_line(usa_timeseries_data.diff(),title='COVID-19 New Cases Over Time: USA',x_axis='Date',y_axis='# New Cases')

# %% [markdown]
# ### Figure 14

# %%
china_timeseries_data = make_dataframe([df_confirmed,df_deaths,df_recovered],['Confirmed','Deaths','Recovered'],'Country','China')
plot_line(china_timeseries_data,title='COVID-19 Cumulative Cases Over Time: China',x_axis='Date',y_axis='# Cumulative Cases')

# %% [markdown]
# ### Figure 15

# %%
plot_line(china_timeseries_data.diff(),title='COVID-19 New Cases Over Time: China',x_axis='Date',y_axis='# New Cases')

# %% [markdown]
# ### Figure 16

# %% [markdown]
# ## Choropleth Maps

# %%
def create_choropleth_map(dataframe,variable,title='COVID-19 Cases Over Time: Globally',x_axis='Date',y_axis='Daily Cases'):
    fig, ax = plt.subplots(1, 1)
    ax.set_ylabel(y_axis,labelpad=20)
    ax.set_title(title,pad=20)
    ax.set_xlabel(x_axis,labelpad=20)
    gdf = geopandas.GeoDataFrame(dataframe)
    gdf.plot(column=variable,ax=ax)

# %%
# Inner Join Two DataFrames
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
mapping = {'United States of America':'USA',\
           'Dem. Rep. Congo':'Democratic Republic of the Congo',\
           'Central African Rep.':'Central African Republic',\
           'Congo':'Republic of the Congo',\
           'Bosnia and Herz.':'Bosnia',\
           'Eq. Guinea':'Equatorial Guinea',\
           'S. Sudan':'South Sudan'\
          }
world.replace(mapping,inplace=True)
gdf = pd.merge(left=df_covid_latest, right=world, left_on='Country', right_on='name')

# %%
## Figure out which countries have to be manually mapped between the 
## COVID dataframe and naturalearth_lowres dataframe
# gdf_tmp = pd.merge(left=df_covid_latest, right=world, left_on='Country', right_on='name',how='outer')[['Country','name']]
# gdf_tmp = gdf_tmp[gdf_tmp.isnull().any(axis=1)]
# [print(row) for row in gdf_tmp.itertuples()]

# %%
create_choropleth_map(gdf,'Confirmed',title='COVID-19 Confirmed Cases',x_axis='Lat',y_axis='Long')

# %% [markdown]
# ### Figure 17

# %%
create_choropleth_map(gdf,'Deaths',title='COVID-19 Deaths',x_axis='Lat',y_axis='Long')

# %% [markdown]
# ### Figure 18

# %%
create_choropleth_map(gdf,'Recovered',title='COVID-19 Recovered Cases',x_axis='Lat',y_axis='Long')

# %% [markdown]
# ### Figure 19
